# %% [markdown]
# # Create a 1D signal GAN for voice recorded signals
# ## Use a very basic GAN architecture that works with a single dimension (1D array)

# %%
import sounddevice as sd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, Audio
from scipy.io.wavfile import write
import os
import torch.nn.functional as F

# %% [markdown]
# # Lets setup some basic configurations

# %%
sample_rate = 48000
duration = 1  # 2 seconds
signal_length = sample_rate * duration

# %% [markdown]
# ## Define the Generator class

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=8, out_dim=1024):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(128, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1024, out_dim),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z)

# %% [markdown]
# ## Define the Discriminator class

# %%
class Discriminator(nn.Module):
    def __init__(self, in_dim=1024):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(in_dim, 128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Custom dataset class for voice signals

# %%
class AudioDataset(Dataset):
    def __init__(self, data_dir, sample_rate=22050, duration=2):
        self.data_dir = data_dir
        self.sample_rate = sample_rate
        self.duration = duration
        self.files = [f for f in os.listdir(data_dir) if f.endswith('.npy')]  # Only .npy files

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.data_dir, self.files[idx])
        # Load numpy array
        waveform = np.load(file_path)
        # Ensure the audio is 2 seconds long
        target_length = self.sample_rate * self.duration
        if waveform.size < target_length:
            # Pad the waveform if it's shorter than 2 seconds
            waveform = np.pad(waveform, (0, target_length - waveform.size), mode='constant')
        else:
            # Trim the waveform if it's longer than duration
            waveform = waveform[:target_length]
        waveform = waveform.astype(np.float32)
        waveform = (waveform - min(waveform)) / (max(waveform) - min(waveform)) * 2 - 1 
        waveform = waveform/np.max(waveform)
        return torch.tensor(waveform,dtype=torch.float32)  # Convert to tensor

# %% [markdown]
# ## Prepare the dataset for training the GAN

# %%
# Create the dataset and dataloader
batch_size = 256
dataset = AudioDataset('audioMNIST/', sample_rate, duration)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
print(len(dataset))
# Out:
# 30000

# %%
# plot the signal 
for batch in dataloader:
    # Plot the generated audio signal
    plt.figure(figsize=(12, 6))
    print(batch[0])
    plt.plot(batch[0], label='Generated Audio Signal', alpha=0.5)
    plt.title('Generated Audio Signal')
    plt.xlabel('Sample Index')
    plt.ylabel('Amplitude')
    plt.legend()
    plt.show()
    break
# Out:
# tensor([-0.0363, -0.0363, -0.0363,  ..., -0.0434, -0.0434, -0.0434])

# %% [markdown]
# ## Initialize the generator and discriminator

# %%
# Set up the GAN
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Hyperparameters
latent_dim = 128
lr = 0.0005
b1 = 0.1
b2 = 0.075
num_epochs = 10
# Initialize generator and discriminator
generator = Generator(latent_dim=latent_dim,out_dim= signal_length)
discriminator = Discriminator(in_dim=signal_length)

# %% [markdown]
# ## Define the loss function and optimizers

# %%
criterion = nn.BCELoss()
g_optimizer = torch.optim.SGD(generator.parameters(), lr=lr, momentum=0.9)
d_optimizer = torch.optim.SGD(discriminator.parameters(), lr=lr, momentum=0.9)
num_epochs = 10

# %%
def hinge_loss_discriminator(real_output, fake_output):
    real_loss = torch.mean(torch.nn.functional.relu(1.0 - real_output))
    fake_loss = torch.mean(torch.nn.functional.relu(1.0 + fake_output))
    return real_loss + fake_loss

def hinge_loss_generator(fake_output):
    return -torch.mean(fake_output)

# %% [markdown]
# ## Training the GAN

# %%
# Lists to store losses
weight_clipping_limit = 0.01  # Weight clipping limit

g_losses = []
d_losses = []
# Training loop
for epoch in range(num_epochs):
    for real_samples in dataloader: # batch is (batch_size, time_steps, features)
        # Train the discriminator
        # Generate fake signal
        z =  (-2.0)*(torch.randn(real_samples.size(0), latent_dim))-1.0
        fake_samples = generator(z).detach()
        real_samples = real_samples
        
        real_output = discriminator(real_samples)
        fake_output = discriminator(fake_samples)

        d_loss = hinge_loss_discriminator(real_output, fake_output)
        discriminator.zero_grad()
        d_loss.backward()
        d_optimizer.step()
        # Weight clipping
        for p in discriminator.parameters():
            p.data.clamp_(-weight_clipping_limit, weight_clipping_limit)

        # Train the generator
        z =  (-2.0)*(torch.randn(real_samples.size(0), latent_dim))-1.0
       
        fake_samples = generator(z)
        fake_output = discriminator(fake_samples.detach())
        g_loss = hinge_loss_generator(fake_output)
        
        generator.zero_grad()
        g_loss.backward()
        g_optimizer.step()

        # Store losses
        g_losses.append(g_loss.item())
        d_losses.append(d_loss.item())
    #if epoch % 100 == 0:
        print(f'Epoch: {epoch}, Generator Loss: {g_loss.item()}, Discriminator Loss: {d_loss.item()}')
# Out:
# Epoch: 0, Generator Loss: -0.49696090817451477, Discriminator Loss: 1.9954564571380615
# Epoch: 0, Generator Loss: -0.4968806505203247, Discriminator Loss: 1.9986515045166016
# Epoch: 0, Generator Loss: -0.49685513973236084, Discriminator Loss: 1.998321533203125
# Epoch: 0, Generator Loss: -0.496762216091156, Discriminator Loss: 1.9985325336456299
# Epoch: 0, Generator Loss: -0.49668940901756287, Discriminator Loss: 1.9982414245605469
# Epoch: 0, Generator Loss: -0.4965546727180481, Discriminator Loss: 1.9983067512512207
# Epoch: 0, Generator Loss: -0.4964640736579895, Discriminator Loss: 1.9978363513946533
# Epoch: 0, Generator Loss: -0.49634459614753723, Discriminator Loss: 1.9978104829788208
# Epoch: 0, Generator Loss: -0.49622347950935364, Discriminator Loss: 1.9977443218231201
# Epoch: 0, Generator Loss: -0.49617379903793335, Discriminator Loss: 1.9977861642837524
# Epoch: 0, Generator Loss: -0.4960317611694336, Discriminator Loss: 1.9974710941314697
# Epoch: 0, Generator Loss: -0.4959574043750763, Discriminator Loss: 1.9968516826629639
# Epoch: 0, Generator Loss: -0.49584537744522095, Discriminator Loss: 1.9967728853225708
# Epoch: 0, Generator Loss: -0.49573639035224915, Discriminator Loss: 1.9966883659362793
# Epoch: 0, Generator Loss: -0.49563825130462646, Discriminator Loss: 1.9963271617889404
# Epoch: 0, Generator Loss: -0.4955000877380371, Discriminator Loss: 1.9967702627182007
# Epoch: 0, Generator Loss: -0.49539270997047424, Discriminator Loss: 1.996324062347412
# Epoch: 0, Generator Loss: -0.4952419400215149, Discriminator Loss: 1.9959276914596558
# Epoch: 0, Generator Loss: -0.49512922763824463, Discriminator Loss: 1.9956334829330444
# Epoch: 0, Generator Loss: -0.49499964714050293, Discriminator Loss: 1.9954423904418945
# Epoch: 0, Generator Loss: -0.494922935962677, Discriminator Loss: 1.9954748153686523
# Epoch: 0, Generator Loss: -0.49476808309555054, Discriminator Loss: 1.9948245286941528
# Epoch: 0, Generator Loss: -0.49465426802635193, Discriminator Loss: 1.9948644638061523
# Epoch: 0, Generator Loss: -0.4945839047431946, Discriminator Loss: 1.9946386814117432
# Epoch: 0, Generator Loss: -0.4944455623626709, Discriminator Loss: 1.994639277458191
# Epoch: 0, Generator Loss: -0.49434876441955566, Discriminator Loss: 1.9947845935821533
# Epoch: 2, Generator Loss: -0.45256507396698, Discriminator Loss: 1.906954050064087
# Epoch: 2, Generator Loss: -0.45297789573669434, Discriminator Loss: 1.912341833114624
# Epoch: 2, Generator Loss: -0.45223602652549744, Discriminator Loss: 1.9104793071746826
# Epoch: 2, Generator Loss: -0.4521070718765259, Discriminator Loss: 1.9043009281158447
# Epoch: 2, Generator Loss: -0.4530699551105499, Discriminator Loss: 1.9047774076461792
# Epoch: 2, Generator Loss: -0.4520346522331238, Discriminator Loss: 1.9078001976013184
# Epoch: 2, Generator Loss: -0.45205819606781006, Discriminator Loss: 1.9044020175933838
# Epoch: 2, Generator Loss: -0.4524156451225281, Discriminator Loss: 1.9023631811141968
# Epoch: 2, Generator Loss: -0.45147180557250977, Discriminator Loss: 1.9140069484710693
# Epoch: 2, Generator Loss: -0.4517088830471039, Discriminator Loss: 1.9063292741775513
# Epoch: 2, Generator Loss: -0.4510551393032074, Discriminator Loss: 1.906447172164917
# Epoch: 2, Generator Loss: -0.4515753388404846, Discriminator Loss: 1.9110349416732788
# Epoch: 2, Generator Loss: -0.4510674774646759, Discriminator Loss: 1.8970448970794678
# Epoch: 3, Generator Loss: -0.4507051110267639, Discriminator Loss: 1.9030814170837402
# Epoch: 3, Generator Loss: -0.4507451057434082, Discriminator Loss: 1.9058574438095093
# Epoch: 3, Generator Loss: -0.45076262950897217, Discriminator Loss: 1.9051679372787476
# Epoch: 3, Generator Loss: -0.450874924659729, Discriminator Loss: 1.9015450477600098
# Epoch: 3, Generator Loss: -0.4507921636104584, Discriminator Loss: 1.9024027585983276
# Epoch: 3, Generator Loss: -0.45013532042503357, Discriminator Loss: 1.8999638557434082
# Epoch: 3, Generator Loss: -0.45083245635032654, Discriminator Loss: 1.9089624881744385
# Epoch: 3, Generator Loss: -0.44990062713623047, Discriminator Loss: 1.9047433137893677
# Epoch: 3, Generator Loss: -0.4501740336418152, Discriminator Loss: 1.9104622602462769
# Epoch: 3, Generator Loss: -0.44968029856681824, Discriminator Loss: 1.9020533561706543
# Epoch: 3, Generator Loss: -0.44938385486602783, Discriminator Loss: 1.8922638893127441
# Epoch: 3, Generator Loss: -0.44896143674850464, Discriminator Loss: 1.9053763151168823
# Epoch: 3, Generator Loss: -0.44896575808525085, Discriminator Loss: 1.9053421020507812
# Epoch: 3, Generator Loss: -0.449268102645874, Discriminator Loss: 1.8981150388717651
# Epoch: 3, Generator Loss: -0.44870230555534363, Discriminator Loss: 1.9059182405471802
# Epoch: 3, Generator Loss: -0.4489326477050781, Discriminator Loss: 1.8974345922470093
# Epoch: 3, Generator Loss: -0.44811978936195374, Discriminator Loss: 1.8975460529327393
# Epoch: 3, Generator Loss: -0.4488208293914795, Discriminator Loss: 1.8962146043777466
# Epoch: 3, Generator Loss: -0.44797345995903015, Discriminator Loss: 1.897946834564209
# Epoch: 3, Generator Loss: -0.4483029544353485, Discriminator Loss: 1.893558144569397
# Epoch: 3, Generator Loss: -0.4486106336116791, Discriminator Loss: 1.8969347476959229
# Epoch: 3, Generator Loss: -0.4426242411136627, Discriminator Loss: 1.8802547454833984
# Epoch: 3, Generator Loss: -0.4429624676704407, Discriminator Loss: 1.8920142650604248
# Epoch: 3, Generator Loss: -0.4419887065887451, Discriminator Loss: 1.8869930505752563
# Epoch: 3, Generator Loss: -0.44261807203292847, Discriminator Loss: 1.8901488780975342
# Epoch: 3, Generator Loss: -0.44255346059799194, Discriminator Loss: 1.8920575380325317
# Epoch: 3, Generator Loss: -0.4427977502346039, Discriminator Loss: 1.8865559101104736
# Epoch: 3, Generator Loss: -0.4416968822479248, Discriminator Loss: 1.8968253135681152
# Epoch: 3, Generator Loss: -0.44191738963127136, Discriminator Loss: 1.8869696855545044
# Epoch: 3, Generator Loss: -0.4417761266231537, Discriminator Loss: 1.8923711776733398
# Epoch: 3, Generator Loss: -0.4420301616191864, Discriminator Loss: 1.8920577764511108
# Epoch: 3, Generator Loss: -0.4411166310310364, Discriminator Loss: 1.8946267366409302
# Epoch: 3, Generator Loss: -0.44119343161582947, Discriminator Loss: 1.8856961727142334
# Epoch: 3, Generator Loss: -0.4415047764778137, Discriminator Loss: 1.8839821815490723
# Epoch: 3, Generator Loss: -0.44170182943344116, Discriminator Loss: 1.8837270736694336
# Epoch: 3, Generator Loss: -0.4404842257499695, Discriminator Loss: 1.8811489343643188
# Epoch: 3, Generator Loss: -0.4416346549987793, Discriminator Loss: 1.8851895332336426
# Epoch: 3, Generator Loss: -0.4407886266708374, Discriminator Loss: 1.8814479112625122
# Epoch: 3, Generator Loss: -0.44035953283309937, Discriminator Loss: 1.8839621543884277
# Epoch: 3, Generator Loss: -0.4399486482143402, Discriminator Loss: 1.8878710269927979
# Epoch: 3, Generator Loss: -0.44040417671203613, Discriminator Loss: 1.8840844631195068
# Epoch: 3, Generator Loss: -0.4395688772201538, Discriminator Loss: 1.879197597503662
# Epoch: 3, Generator Loss: -0.4396871328353882, Discriminator Loss: 1.884799838066101
# Epoch: 3, Generator Loss: -0.439932644367218, Discriminator Loss: 1.8861812353134155
# Epoch: 3, Generator Loss: -0.43942245841026306, Discriminator Loss: 1.8822636604309082
# Epoch: 3, Generator Loss: -0.438843309879303, Discriminator Loss: 1.8815844058990479
# KeyboardInterrupt

# %% [markdown]
# ## Plot the losses

# %%
# Plot the losses
plt.figure(figsize=(12, 6))
plt.plot(g_losses, label='Generator Loss')
plt.plot(d_losses, label='Discriminator Loss')
plt.title('GAN Training Losses')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Generate new signals after training

# %%
# Set the generator to evaluation mode
generator.eval()
# Generate and visualize a sample output
with torch.no_grad():
    z =  torch.tanh(torch.randn(1, latent_dim))
    generated_audio = generator(z).detach().numpy().flatten()
print(generated_audio.shape)
# Plot the generated audio signal
plt.figure(figsize=(12, 6))
plt.plot(generated_audio, label='Generated Audio Signal', alpha=0.5)
plt.title('Generated Audio Signal')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
# (48000,)

# %%
# saving the output
np.save('generated/generated.npy', generated_audio)
from scipy.io.wavfile import write

# Assuming the array values are in the range of int16 for WAV format
# Scale the array if necessary
generated_audio = np.int16(generated_audio / np.max(np.abs(generated_audio)) * 32767)

# Save the array as a WAV file
write('generated/generated.wav', sample_rate, generated_audio)
