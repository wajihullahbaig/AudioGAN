# %%
import librosa    
import numpy as np
from scipy.io import wavfile
import scipy.signal as signal
import os

def down_sample(source_directory, target_directory):
    # Ensure the target directory exists
    new_sample_rate = 16000
    os.makedirs(target_directory, exist_ok=True)
    # Iterate through all files and subdirectories in the source directory
    for root, _, files in os.walk(source_directory):
        file_count = 0
        for filename in files:
            if filename.endswith('.wav'):
                # Construct full file path
                file_path = os.path.join(root, filename)
                # Read the WAV file
                
                sample_rate, audio_data = wavfile.read(file_path)
                # Downsample the audio to 16 kH
                # Check if audio is stereo (2 channels)
                if audio_data.ndim == 2:
                    # Convert stereo to mono by averaging the two channels
                    audio_data = audio_data.mean(axis=1)
                
                # Resample the audio to 16 kHz
                number_of_samples = int(len(audio_data) * new_sample_rate / sample_rate)
                audio_data_resampled = signal.resample(audio_data, number_of_samples)

                # Apply gain to increase volume (e.g., gain factor of 2.0)
                gain_factor = 2.0
                audio_data_resampled *= gain_factor
                # Ensure the output data type is correct (16-bit PCM)
                audio_data_resampled = np.clip(audio_data_resampled, -32768, 32767)  # Clip to int16 range
                audio_data_resampled = audio_data_resampled.astype(np.int16)
                
                # Save the downsampled audio to a new WAV file
                # Create a new filename
                filename_16khz = os.path.splitext(filename)[0] + '.wav'
                full_file_path = os.path.join(target_directory, filename_16khz)
                
                # Save the resampled audio to a new WAV file
                wavfile.write(full_file_path, new_sample_rate, audio_data_resampled)                
                
               
                if file_count %100 == 0:
                    print("processing file:"+full_file_path)
                    print("sample_rate:", str(sample_rate))
                    print("re sample_rate:", str(new_sample_rate))
                    print(f"file count {file_count}")
                file_count +=1
                
# Example usage
source_directory_path = 'C:/Users/Acer/work/git/AudioMNIST/data'  
target_directory_path = 'C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz'

# %%
down_sample(source_directory_path, target_directory_path)
# Out:
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_01_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_01_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_01_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_01_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_01_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_02_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_02_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_02_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_02_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_02_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_03_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_03_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_03_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_03_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_03_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_04_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_04_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_04_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_04_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_04_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_05_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_05_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_05_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_05_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_05_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_06_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_06_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_06_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_06_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_06_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_07_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_07_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_07_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_07_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_07_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_08_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_08_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_08_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_08_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_08_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_09_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_09_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_09_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_09_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_09_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_10_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_10_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_10_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_10_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_10_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_11_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_11_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_11_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_11_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_11_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_12_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_12_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_12_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_12_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_12_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_13_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_13_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_13_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_13_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_13_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_14_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_14_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_14_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_14_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_14_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_15_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_15_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_15_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_15_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_15_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_16_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_16_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_16_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_16_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_16_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_17_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_17_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_17_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_17_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_17_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_18_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_18_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_18_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_18_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_18_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_19_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_19_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_19_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_19_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_19_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_20_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_20_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_20_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_20_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_20_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_21_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_21_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_21_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_21_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_21_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_22_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_22_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_22_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_22_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_22_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_23_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_23_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_23_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_23_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_23_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_24_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_24_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_24_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_24_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_24_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_25_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_25_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_25_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_25_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_25_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_26_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_26_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_26_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_26_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_26_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_27_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_27_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_27_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_27_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_27_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_28_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_28_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_28_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_28_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_28_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_29_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_29_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_29_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_29_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_29_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_30_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_30_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_30_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_30_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_30_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_31_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_31_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_31_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_31_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_31_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_32_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_32_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_32_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_32_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_32_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_33_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_33_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_33_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_33_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_33_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_34_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_34_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_34_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_34_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_34_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_35_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_35_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_35_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_35_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_35_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_36_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_36_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_36_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_36_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_36_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_37_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_37_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_37_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_37_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_37_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_38_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_38_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_38_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_38_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_38_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_39_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_39_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_39_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_39_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_39_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_40_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_40_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_40_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_40_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_40_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_41_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_41_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_41_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_41_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_41_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_42_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_42_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_42_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_42_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_42_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_43_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_43_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_43_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_43_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_43_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_44_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_44_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_44_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_44_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_44_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_45_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_45_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_45_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_45_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_45_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_46_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_46_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_46_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_46_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_46_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_47_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_47_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_47_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_47_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_47_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_48_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_48_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_48_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_48_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_48_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_49_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_49_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_49_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_49_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_49_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_50_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_50_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_50_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_50_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_50_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_51_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_51_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_51_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_51_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_51_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_52_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_52_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_52_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_52_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_52_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_53_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_53_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_53_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_53_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_53_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_54_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_54_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_54_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_54_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_54_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_55_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_55_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_55_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_55_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_55_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_56_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_56_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_56_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_56_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_56_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_57_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_57_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_57_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_57_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_57_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_58_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_58_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_58_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_58_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_58_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_59_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_59_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_59_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_59_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_59_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\0_60_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\2_60_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\4_60_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\6_60_0.wav
# sample_rate: 48000
# re sample_rate: 16000
# processing file:C:/Users/Acer/work/git/AudioGAN/audioMNIST_16khz\8_60_0.wav
# sample_rate: 48000
# re sample_rate: 16000
